# %% [markdown]
# # Projet :

# %% [markdown]
# ## Analyse des données du marché du jeu vidéo de 1985 à 2016

# %%
import pandas as pd, seaborn as sb, matplotlib as mpl

# %%
df = pd.read_csv('data/videoGames.csv').dropna().sort_values('Year_of_Release', ascending=False)
df
# Out:
#                                                    Name Platform  \
# 5936                             Imagine: Makeup Artist       DS
# 14086  Phantasy Star Online 2 Episode 4: Deluxe Package      PS4
# 16385                  Brothers Conflict: Precious Baby      PSV
# 16222  Phantasy Star Online 2 Episode 4: Deluxe Package      PSV
# 16718                               Winning Post 8 2016      PSV
# ...                                                 ...      ...
# 16376                 PDC World Championship Darts 2008      PSP
# 16409                                     Freaky Flyers       GC
# 16452                                         Inversion       PC
# 16462                       Hakuouki: Shinsengumi Kitan      PS3
# 16526                                      Virtua Quest       GC
#
#        Year_of_Release         Genre           Publisher  NA_Sales  EU_Sales  \
# 5936            2020.0    Simulation             Ubisoft      0.27       0.0
# 14086           2017.0  Role-Playing                Sega      0.00       0.0
# 16385           2017.0        Action        Idea Factory      0.00       0.0
# 16222           2017.0  Role-Playing                Sega      0.00       0.0
# 16718           2016.0    Simulation          Tecmo Koei      0.00       0.0
# ...                ...           ...                 ...       ...       ...
# 16376              NaN        Sports  Oxygen Interactive      0.01       0.0
# 16409              NaN        Racing             Unknown      0.01       0.0
# 16452              NaN       Shooter  Namco Bandai Games      0.01       0.0
# 16462              NaN     Adventure             Unknown      0.01       0.0
# 16526              NaN  Role-Playing             Unknown      0.01       0.0
#
#        JP_Sales  Other_Sales  Global_Sales  Critic_Score  Critic_Count  \
# 5936       0.00         0.02          0.29           NaN           NaN
# 14086      0.04         0.00          0.04           NaN           NaN
# 16385      0.01         0.00          0.01           NaN           NaN
# 16222      0.01         0.00          0.01           NaN           NaN
# 16718      0.01         0.00          0.01           NaN           NaN
# ...         ...          ...           ...           ...           ...
# 16376      0.00         0.00          0.01          43.0           7.0
# 16409      0.00         0.00          0.01          69.0          14.0
# 16452      0.00         0.00          0.01          59.0           6.0
# 16462      0.00         0.00          0.01           NaN           NaN
# 16526      0.00         0.00          0.01          55.0          19.0
#
#       User_Score  User_Count                     Developer Rating
# 5936         tbd         NaN                       Ubisoft      E
# 14086        NaN         NaN                           NaN    NaN
# 16385        NaN         NaN                           NaN    NaN
# 16222        NaN         NaN                           NaN    NaN
# 16718        NaN         NaN                           NaN    NaN
# ...          ...         ...                           ...    ...
# 16376        tbd         NaN            Oxygen Interactive   E10+
# 16409        6.5         6.0                        Midway      T
# 16452        6.7       107.0             Saber Interactive      M
# 16462        NaN         NaN                           NaN    NaN
# 16526        5.5        12.0  Artificial Mind and Movement      T
#
# [16719 rows x 16 columns]

# %%
df.shape
# Out:
# (16719, 16)

# %%
df.dtypes
# Out:
# Name                object
# Platform            object
# Year_of_Release    float64
# Genre               object
# Publisher           object
# NA_Sales           float64
# EU_Sales           float64
# JP_Sales           float64
# Other_Sales        float64
# Global_Sales       float64
# Critic_Score       float64
# Critic_Count       float64
# User_Score          object
# User_Count         float64
# Developer           object
# Rating              object
# dtype: object

# %%
#catplot
g = sb.catplot(x="Global_Sales", y="Genre",data=df, kind='bar')

# %%
#Nuages de points
df.sample(500).plot.scatter(x='Critic_Score', y='Global_Sales')
# Out:
# <AxesSubplot:xlabel='Critic_Score', ylabel='Global_Sales'>

# %%
#Courbes de distribution
sb.distplot(df['Global_Sales'], vertical=False)
# Out:
# <AxesSubplot:xlabel='Global_Sales'>

# %%
sb.distplot(df['Critic_Score'], vertical=False)
# Out:
# <AxesSubplot:xlabel='Critic_Score'>

# %%
sb.distplot(df['Year_of_Release'], vertical=False, bins=30)
# Out:
# <AxesSubplot:xlabel='Year_of_Release'>

# %%
#GroupBy
df2 = df[['Platform', 'Global_Sales']].groupby('Platform').sum().sort_values('Global_Sales', ascending=False)
df2
# Out:
#           Global_Sales
# Platform
# PS2            1255.64
# X360            971.63
# PS3             939.43
# Wii             908.13
# DS              807.10
# PS              730.68
# GBA             318.50
# PS4             314.23
# PSP             294.30
# PC              260.30
# 3DS             259.09
# XB              258.26
# GB              255.45
# NES             251.07
# N64             218.88
# SNES            200.05
# GC              199.36
# XOne            159.44
# 2600             97.08
# WiiU             82.16
# PSV              54.12
# SAT              33.59
# GEN              30.78
# DC               15.97
# SCD               1.87
# NG                1.44
# WS                1.42
# TG16              0.16
# 3DO               0.10
# GG                0.04
# PCFX              0.03

# %%
df3 = df[['Genre', 'Global_Sales']].groupby('Genre').sum().sort_values('Global_Sales', ascending=False)
df3
# Out:
#               Global_Sales
# Genre
# Action             1745.27
# Sports             1332.00
# Shooter            1052.94
# Role-Playing        934.40
# Platform            828.08
# Misc                803.18
# Racing              728.90
# Fighting            447.48
# Simulation          390.42
# Puzzle              243.02
# Adventure           237.69
# Strategy            174.50

# %%
df4 = df[['Publisher', 'Global_Sales']].groupby('Publisher').sum().sort_values('Global_Sales', ascending=False)
df4
# Out:
#                              Global_Sales
# Publisher
# Nintendo                          1788.81
# Electronic Arts                   1116.96
# Activision                         731.16
# Sony Computer Entertainment        606.48
# Ubisoft                            471.61
# ...                                   ...
# Takuyo                               0.01
# EON Digital Entertainment            0.01
# Paradox Development                  0.01
# Red Flagship                         0.01
# UIG Entertainment                    0.01
#
# [581 rows x 1 columns]

# %%
df5 = df[['Developer', 'Global_Sales']].groupby('Developer').sum().sort_values('Global_Sales', ascending=False)
df5
# Out:
#                             Global_Sales
# Developer
# Nintendo                          531.71
# EA Sports                         175.38
# EA Canada                         142.32
# Ubisoft                           132.54
# Rockstar North                    119.47
# ...                                  ...
# Inferno Games                       0.01
# Infinite Dreams, Paragon 5          0.01
# Interchannel-Holon                  0.01
# Societe Pollene                     0.01
# TML-Studios                         0.01
#
# [1696 rows x 1 columns]

# %%
#lmplot
g = sb.lmplot(y="Global_Sales", x="Critic_Score", data=df.sample(100))

# %%
#heatmap
g = sb.heatmap(df.corr())
